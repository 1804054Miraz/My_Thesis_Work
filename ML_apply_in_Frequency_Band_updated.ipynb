# %% [markdown]
# <a href="https://colab.research.google.com/github/1804054Miraz/My_Thesis_Work/blob/main/ML_apply_in_Frequency_Band_updated.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
import numpy as np
import os
import pandas as pd
import statistics as st
import scipy.stats as scst
from scipy.stats import skew
from scipy.stats import kurtosis
from scipy.stats import entropy
from scipy.stats import normaltest
import seaborn as sns
from sklearn.model_selection import train_test_split, cross_val_score, KFold
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.impute import SimpleImputer
from sklearn.metrics import accuracy_score, classification_report
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPClassifier
from keras.models import Sequential
from keras.layers import LSTM, Dense
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report
import time
from sklearn.ensemble import BaggingClassifier

# %%
path = '/content/drive/MyDrive/Dataset/Features/Katz_Fd_Features_a_c.csv'
Katz_Fd_Features_a_c = pd.read_csv(path)
# Katz_Fd_Features_a_c = Katz_Fd_Features_a_c.replace(0, Katz_Fd_Features_a_c.mean())
Katz_Fd_Features_a_c = Katz_Fd_Features_a_c.drop(7620)
# Katz_Fd_Features_a_c = Katz_Fd_Features_a_c.reset_index(drop=True)

# %%
Katz_Fd_Features_a_c
# Out:
#            FP2     label
# 0     1.655864  addicted
# 1     1.367933  addicted
# 2     1.584968  addicted
# 3     1.282758  addicted
# 4     1.461674  addicted
# ...        ...       ...
# 7616  1.819097    normal
# 7617  1.538744    normal
# 7618  1.716444    normal
# 7619  1.556286    normal
# 7621  1.598684    normal
#
# [7621 rows x 2 columns]

# %%
path = '/content/drive/MyDrive/Dataset/Features/merged_alpha_a_c.csv'
merged_alpha_a_c = pd.read_csv(path)
# merged_alpha_a_c=merged_alpha_a_c.drop(columns=['X_PS','Y_PS','nd_PS'], axis=False)
# merged_alpha_a_c = merged_alpha_a_c.replace(0, merged_alpha_a_c.mean())
merged_alpha_a_c = merged_alpha_a_c.drop(7620)
# merged_alpha_a_c = merged_alpha_a_c.reset_index(drop=True)

# %%
path = '/content/drive/MyDrive/Dataset/Features/merged_beta_a_c.csv'
merged_beta_a_c = pd.read_csv(path)
# merged_beta_a_c=merged_beta_a_c.drop(columns=['X_PS','Y_PS','nd_PS'], axis=False)
# merged_beta_a_c = merged_beta_a_c.replace(0, merged_beta_a_c.mean())
merged_beta_a_c = merged_beta_a_c.drop(7620)
# merged_beta_a_c = merged_beta_a_c.reset_index(drop=True)

# %%
path = '/content/drive/MyDrive/Dataset/Features/merged_delta_a_c.csv'
merged_delta_a_c = pd.read_csv(path)
# merged_delta_a_c=merged_delta_a_c.drop(columns=['X_PS','Y_PS','nd_PS'], axis=False)
# merged_delta_a_c = merged_delta_a_c.replace(0, merged_delta_a_c.mean())
merged_delta_a_c = merged_delta_a_c.drop(7620)
# merged_delta_a_c = merged_delta_a_c.reset_index(drop=True)

# %%
path = '/content/drive/MyDrive/Dataset/Features/merged_gamma_a_c.csv'
merged_gamma_a_c = pd.read_csv(path)
# merged_gamma_a_c=merged_gamma_a_c.drop(columns=['X_PS','Y_PS','nd_PS'], axis=False)
# merged_gamma_a_c = merged_gamma_a_c.replace(0, merged_gamma_a_c.mean())
merged_gamma_a_c = merged_gamma_a_c.drop(7620)
# merged_gamma_a_c = merged_gamma_a_c.reset_index(drop=True)

# %%
path = '/content/drive/MyDrive/Dataset/Features/merged_theta_a_c.csv'
merged_theta_a_c = pd.read_csv(path)
# merged_theta_a_c=merged_theta_a_c.drop(columns=['X_PS','Y_PS','nd_PS'], axis=False)
# merged_theta_a_c = merged_theta_a_c.replace(0, merged_theta_a_c.mean())
merged_theta_a_c = merged_theta_a_c.drop(7620)
# merged_theta_a_c = merged_theta_a_c.reset_index(drop=True)

# %%
merged_theta_a_c
# Out:
#            FP1_PS       FP2_PS        F7_PS       F8_PS      AF1_PS  \
# 0      867.358262   812.623502   114.844549  128.518077  345.314190
# 1       46.947161    56.036419    41.483061   57.415304   32.434629
# 2      513.895017   356.624987   111.283520   41.727985  205.243254
# 3     1206.244099  1013.869992   121.663298  113.079481  341.070294
# 4      188.085431   201.701573   113.814156  111.713754  141.423238
# ...           ...          ...          ...         ...         ...
# 7616   387.006751   395.667173   628.113616  347.940998  270.572518
# 7617   485.019482   641.333229   306.276485  503.409145  266.294508
# 7618   133.311611   125.183330    81.844960  305.980831  106.394475
# 7619   662.399310   496.651847  1729.257484  553.260650  538.113874
# 7621   679.747373   477.093870  1656.886684  612.609707  392.600707
#
#           AF2_PS       FZ_PS       F4_PS       F3_PS      FC6_PS  ...  \
# 0     265.050318  127.116662  124.594087   99.373225   37.712022  ...
# 1      30.244985   29.493919   28.616580   33.431262   37.035652  ...
# 2     126.419959   68.668789   44.855858   79.681575   14.904409  ...
# 3     258.281794  125.797147  122.250391   94.327721   48.556339  ...
# 4     133.849981   78.771697   47.422484   66.006383   39.382516  ...
# ...          ...         ...         ...         ...         ...  ...
# 7616  262.573520  243.449727  201.271799  260.013387  165.455701  ...
# 7617  317.123635  124.807857  232.667987  211.878019  213.931449  ...
# 7618  130.640291   78.352414  156.563887   42.734269  286.682363  ...
# 7619  403.633449  275.923420  250.409735  587.224147  284.255502  ...
# 7621  285.254937  253.180665  200.923702  554.358116  325.818172  ...
#
#            PO8_PS      FCZ_PS      POZ_PS       OZ_PS       P2_PS       P1_PS  \
# 0      118.574055   37.785561  169.310655  195.500180   91.600778   93.463860
# 1       68.931691   12.781637   58.590839  106.070021   24.507708   28.567905
# 2       88.183772   21.042309  102.516398  125.325385   45.060627   50.756667
# 3      155.230308   43.421813  153.778105  174.708240  112.189054   96.867541
# 4      245.235339   31.624889  110.917342  147.464934   72.364951   49.042605
# ...           ...         ...         ...         ...         ...         ...
# 7616   465.746708   48.646156  453.344715  736.577537  304.593989  242.679832
# 7617  2435.543467   38.120911  575.246662  794.291896  353.870979  213.078726
# 7618   957.563815   25.227575  420.478181  798.872834  197.513955  189.951922
# 7619  1265.618590   68.597395  518.968173  816.233528  285.604971  320.296970
# 7621   979.389913  250.780951  496.847962  870.474649  353.095086  458.454958
#
#           CPZ_PS        nd_PS         Y_PS     label
# 0      27.167346   827.992204    95.120775  addicted
# 1       4.400512    44.465777    82.141517  addicted
# 2      10.394625   488.971398    84.446648  addicted
# 3      22.398956  1156.497875    62.752039  addicted
# 4      11.421986   181.886437   177.473279  addicted
# ...          ...          ...          ...       ...
# 7616  143.422872   949.912561  1282.995635    normal
# 7617   64.897273   788.683676   419.213473    normal
# 7618   32.803412   976.774527   428.238612    normal
# 7619   98.369361   889.868940  3318.701381    normal
# 7621  275.569409  1213.438862  2734.527193    normal
#
# [7621 rows x 65 columns]

# %%
# Assuming 'merged_alpha_a_c' is your DataFrame
X = merged_alpha_a_c.iloc[:, :-1]
y = merged_alpha_a_c.iloc[:, -1]
# Encode the target variable if it's categorical
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

xgb_classifier = XGBClassifier()
xgb_scores = cross_val_score(xgb_classifier, X, y_encoded, cv=KFold(n_splits=10, shuffle=True, random_state=42))
print("XGBoost Mean Accuracy:", xgb_scores.mean())

# Assuming 'merged_beta_a_c' is your DataFrame
X = merged_beta_a_c.iloc[:, :-1]
y = merged_beta_a_c.iloc[:, -1]
# Encode the target variable if it's categorical
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)
# XGBoost
xgb_classifier = XGBClassifier()
xgb_scores = cross_val_score(xgb_classifier, X, y_encoded, cv=KFold(n_splits=10, shuffle=True, random_state=42))
# print("XGBoost Cross-Validation Scores:", xgb_scores)
print("XGBoost Mean Accuracy:", xgb_scores.mean())


# Assuming 'merged_beta_a_c' is your DataFrame
X = merged_delta_a_c.iloc[:, :-1]
y = merged_delta_a_c.iloc[:, -1]
# Encode the target variable if it's categorical
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)
# XGBoost
xgb_classifier = XGBClassifier()
xgb_scores = cross_val_score(xgb_classifier, X, y_encoded, cv=KFold(n_splits=10, shuffle=True, random_state=42))
# print("XGBoost Cross-Validation Scores:", xgb_scores)
print("XGBoost Mean Accuracy:", xgb_scores.mean())


# Assuming 'merged_gamma_a_c' is your DataFrame
X = merged_theta_a_c.iloc[:, :-1]
y = merged_theta_a_c.iloc[:, -1]

# Encode the target variable if it's categorical
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)
# XGBoost
xgb_classifier = XGBClassifier()
xgb_scores = cross_val_score(xgb_classifier, X, y_encoded, cv=KFold(n_splits=10, shuffle=True, random_state=42))
# print("XGBoost Cross-Validation Scores:", xgb_scores)
print("XGBoost Mean Accuracy:", xgb_scores.mean())


# Assuming 'merged_gamma_a_c' is your DataFrame
X = merged_gamma_a_c.iloc[:, :-1]
y = merged_gamma_a_c.iloc[:, -1]

# Encode the target variable if it's categorical
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# XGBoost
xgb_classifier = XGBClassifier()
xgb_scores = cross_val_score(xgb_classifier, X, y_encoded, cv=KFold(n_splits=10, shuffle=True, random_state=42))
# print("XGBoost Cross-Validation Scores:", xgb_scores)
print("XGBoost Mean Accuracy:", xgb_scores.mean())
# Out:
# XGBoost Mean Accuracy: 0.7857237455409816
# XGBoost Mean Accuracy: 0.9098530114928295
# XGBoost Mean Accuracy: 0.747934145846448
# XGBoost Mean Accuracy: 0.7803409321541229
# XGBoost Mean Accuracy: 0.9574859908566475

# %%
# Assuming 'merged_alpha_a_c' is your DataFrame
X = Katz_Fd_Features_a_c.iloc[:, :-1]
y = Katz_Fd_Features_a_c.iloc[:, -1]

# Encode the target variable if it's categorical
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Support Vector Machine (SVM)
svm_classifier = make_pipeline(StandardScaler(), SVC())
svm_scores = cross_val_score(svm_classifier, X, y_encoded, cv=KFold(n_splits=10, shuffle=True, random_state=42))
# print("SVM Cross-Validation Scores:", svm_scores)
print("SVM Mean Accuracy:", svm_scores.mean())

# XGBoost
xgb_classifier = XGBClassifier()
xgb_scores = cross_val_score(xgb_classifier, X, y_encoded, cv=KFold(n_splits=10, shuffle=True, random_state=42))
# print("XGBoost Cross-Validation Scores:", xgb_scores)
print("XGBoost Mean Accuracy:", xgb_scores.mean())

# Random Forest
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)
rf_scores = cross_val_score(rf_classifier, X, y_encoded, cv=KFold(n_splits=10, shuffle=True, random_state=42))
# print("Random Forest Cross-Validation Scores:", rf_scores)
print("Random Forest Mean Accuracy:", rf_scores.mean())
# Out:
# SVM Cross-Validation Scores: [0.54390564 0.56487549 0.59973753 0.59055118 0.60498688 0.59186352
#  0.61154856 0.53018373 0.57086614 0.57349081]
# SVM Mean Accuracy: 0.5782009473586445
# XGBoost Cross-Validation Scores: [0.55307995 0.56618611 0.56955381 0.55643045 0.58530184 0.57742782
#  0.57217848 0.52887139 0.5328084  0.57480315]
# XGBoost Mean Accuracy: 0.5616641383129861
# Random Forest Cross-Validation Scores: [0.52948886 0.51900393 0.52624672 0.52099738 0.54068241 0.52362205
#  0.53149606 0.51968504 0.53937008 0.5183727 ]
# Random Forest Mean Accuracy: 0.5268965232556939

# %%
# merged_gamma_katz_a_c = merged_gamma_katz_a_c.drop(7620)
# If you want to reset the index after removing the row
# merged_gamma_katz_a_c = merged_gamma_katz_a_c.reset_index(drop=True)

# %%
# merged_beta_gamma_a_c = pd.concat([merged_beta_a_c,merged_gamma_a_c], axis=1)
# # merged_beta_gamma_a_c

# %%
# merged_beta_gamma_a_c.drop('label', axis=1, inplace=True)

# %%
# merged_beta_gamma_a_c['label']='normal'
# merged_beta_gamma_a_c.loc[0:3810, 'label'] = 'addicted'

# %%
# Assuming 'new_dataframe' is your DataFrame
X = merged_alpha_a_c.iloc[:, :-1]
y = merged_alpha_a_c.iloc[:, -1]

# Encode the target variable if it's categorical
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Support Vector Machine (SVM)
# start_time = time.time()
svm_classifier = make_pipeline(StandardScaler(), SVC())
svm_predictions = cross_val_predict(svm_classifier, X, y_encoded, cv=KFold(n_splits=10, shuffle=True, random_state=42))
svm_accuracy = accuracy_score(y_encoded, svm_predictions)
# svm_precision = precision_score(y_encoded, svm_predictions)
# svm_recall = recall_score(y_encoded, svm_predictions)
# svm_f1 = f1_score(y_encoded, svm_predictions)
# svm_processing_time = time.time() - start_time

print("SVM Metrics:")
print("Accuracy:", svm_accuracy)
# print("Precision:", svm_precision)
# print("Recall:", svm_recall)
# print("F1 Score:", svm_f1)
# print("Processing Time:", svm_processing_time)

# XGBoost
# start_time = time.time()
xgb_classifier = XGBClassifier()
xgb_predictions = cross_val_predict(xgb_classifier, X, y_encoded, cv=KFold(n_splits=10, shuffle=True, random_state=42))
xgb_accuracy = accuracy_score(y_encoded, xgb_predictions)
# xgb_precision = precision_score(y_encoded, xgb_predictions)
# xgb_recall = recall_score(y_encoded, xgb_predictions)
# xgb_f1 = f1_score(y_encoded, xgb_predictions)
# xgb_processing_time = time.time() - start_time

print("\nXGBoost Metrics:")
print("Accuracy:", xgb_accuracy)
# print("Precision:", xgb_precision)
# print("Recall:", xgb_recall)
# print("F1 Score:", xgb_f1)
# print("Processing Time:", xgb_processing_time)

# Random Forest
# start_time = time.time()
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)
rf_predictions = cross_val_predict(rf_classifier, X, y_encoded, cv=KFold(n_splits=10, shuffle=True, random_state=42))
rf_accuracy = accuracy_score(y_encoded, rf_predictions)
# rf_precision = precision_score(y_encoded, rf_predictions)
# rf_recall = recall_score(y_encoded, rf_predictions)
# rf_f1 = f1_score(y_encoded, rf_predictions)
# rf_processing_time = time.time() - start_time

print("\nRandom Forest Metrics:")
print("Accuracy:", rf_accuracy)
# print("Precision:", rf_precision)
# print("Recall:", rf_recall)
# print("F1 Score:", rf_f1)
# print("Processing Time:", rf_processing_time)


# Ensemble Subspace of k-Nearest Neighbors
# start_time_ensemble_knn = time.time()
knn_classifier = KNeighborsClassifier(n_neighbors=5)
ensemble_knn_classifier = BaggingClassifier(base_estimator=knn_classifier, n_estimators=10, random_state=42)

ensemble_knn_scores = cross_val_predict(ensemble_knn_classifier, X, y_encoded, cv=KFold(n_splits=10, shuffle=True, random_state=42))
ensemble_knn_accuracy = accuracy_score(y_encoded, ensemble_knn_scores)
# ensemble_knn_precision = precision_score(y_encoded, ensemble_knn_scores)
# ensemble_knn_recall = recall_score(y_encoded, ensemble_knn_scores)
# ensemble_knn_f1 = f1_score(y_encoded, ensemble_knn_scores)
# ensemble_knn_processing_time = time.time() - start_time_ensemble_knn

print("\nEnsemble Subspace of k-Nearest Neighbors Metrics:")
print("Accuracy:", ensemble_knn_accuracy)
# print("Precision:", ensemble_knn_precision)
# print("Recall:", ensemble_knn_recall)
# print("F1 Score:", ensemble_knn_f1)
# print("Processing Time:", ensemble_knn_processing_time)

# LSTM Model
def create_lstm_model(input_shape):
    model = Sequential()
    model.add(LSTM(64, input_shape=input_shape, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Convert DataFrame to numpy array
X_np = X.values
X_np = X_np.reshape((X_np.shape[0], 1, X_np.shape[1]))

# 10-fold cross-validation
kfold = KFold(n_splits=10, shuffle=True, random_state=42)

accuracy_scores = []
# precision_scores = []
# recall_scores = []
# f1_scores = []

for train_idx, test_idx in kfold.split(X_np):
    X_train, X_test = X_np[train_idx], X_np[test_idx]
    y_train, y_test = y_encoded[train_idx], y_encoded[test_idx]

    # Create and fit LSTM model
    input_shape = (X_train.shape[1], X_train.shape[2])
    lstm_model = create_lstm_model(input_shape)
    lstm_model.fit(X_train, y_train, epochs=10, batch_size=32, verbose=0)

    # Predictions
    y_pred_probs = lstm_model.predict(X_test)
    y_pred = (y_pred_probs > 0.5).astype(int).flatten()

    # Evaluate metrics
    accuracy_scores.append(accuracy_score(y_test, y_pred))
    # precision_scores.append(precision_score(y_test, y_pred))
    # recall_scores.append(recall_score(y_test, y_pred))
    # f1_scores.append(f1_score(y_test, y_pred))

print("\nLSTM Metrics:")
print("LSTM Model Accuracy:", np.mean(accuracy_scores))
# print("LSTM Model Precision:", np.mean(precision_scores))
# print("LSTM Model Recall:", np.mean(recall_scores))
# print("LSTM Model F1 Score:", np.mean(f1_scores))
# Out:
# SVM Metrics:
# Accuracy: 0.7289069675895552
#
# XGBoost Metrics:
# Accuracy: 0.7857236583125574
#
# Random Forest Metrics:
# Accuracy: 0.7537068626164546
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# Ensemble Subspace of k-Nearest Neighbors Metrics:
# Accuracy: 0.7299566985959848
# 24/24 [==============================] - 0s 2ms/step
# 24/24 [==============================] - 0s 2ms/step
# 24/24 [==============================] - 0s 1ms/step
# 24/24 [==============================] - 0s 3ms/step
# 24/24 [==============================] - 0s 2ms/step
# 24/24 [==============================] - 0s 2ms/step
# 24/24 [==============================] - 0s 2ms/step
# 24/24 [==============================] - 1s 3ms/step
# 24/24 [==============================] - 0s 2ms/step
# 24/24 [==============================] - 0s 2ms/step
#
# LSTM Metrics:
# LSTM Model Accuracy: 0.6594866582044216

# %%
# Assuming 'new_dataframe' is your DataFrame
X = merged_beta_a_c.iloc[:, :-1]
y = merged_beta_a_c.iloc[:, -1]

# Encode the target variable if it's categorical
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Support Vector Machine (SVM)
# start_time = time.time()
svm_classifier = make_pipeline(StandardScaler(), SVC())
svm_predictions = cross_val_predict(svm_classifier, X, y_encoded, cv=KFold(n_splits=10, shuffle=True, random_state=42))
svm_accuracy = accuracy_score(y_encoded, svm_predictions)
# svm_precision = precision_score(y_encoded, svm_predictions)
# svm_recall = recall_score(y_encoded, svm_predictions)
# svm_f1 = f1_score(y_encoded, svm_predictions)
# svm_processing_time = time.time() - start_time

print("SVM Metrics:")
print("Accuracy:", svm_accuracy)
# print("Precision:", svm_precision)
# print("Recall:", svm_recall)
# print("F1 Score:", svm_f1)
# print("Processing Time:", svm_processing_time)

# XGBoost
# start_time = time.time()
xgb_classifier = XGBClassifier()
xgb_predictions = cross_val_predict(xgb_classifier, X, y_encoded, cv=KFold(n_splits=10, shuffle=True, random_state=42))
xgb_accuracy = accuracy_score(y_encoded, xgb_predictions)
# xgb_precision = precision_score(y_encoded, xgb_predictions)
# xgb_recall = recall_score(y_encoded, xgb_predictions)
# xgb_f1 = f1_score(y_encoded, xgb_predictions)
# xgb_processing_time = time.time() - start_time

print("\nXGBoost Metrics:")
print("Accuracy:", xgb_accuracy)
# print("Precision:", xgb_precision)
# print("Recall:", xgb_recall)
# print("F1 Score:", xgb_f1)
# print("Processing Time:", xgb_processing_time)

# Random Forest
# start_time = time.time()
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)
rf_predictions = cross_val_predict(rf_classifier, X, y_encoded, cv=KFold(n_splits=10, shuffle=True, random_state=42))
rf_accuracy = accuracy_score(y_encoded, rf_predictions)
# rf_precision = precision_score(y_encoded, rf_predictions)
# rf_recall = recall_score(y_encoded, rf_predictions)
# rf_f1 = f1_score(y_encoded, rf_predictions)
# rf_processing_time = time.time() - start_time

print("\nRandom Forest Metrics:")
print("Accuracy:", rf_accuracy)
# print("Precision:", rf_precision)
# print("Recall:", rf_recall)
# print("F1 Score:", rf_f1)
# print("Processing Time:", rf_processing_time)


# Ensemble Subspace of k-Nearest Neighbors
# start_time_ensemble_knn = time.time()
knn_classifier = KNeighborsClassifier(n_neighbors=5)
ensemble_knn_classifier = BaggingClassifier(base_estimator=knn_classifier, n_estimators=10, random_state=42)

ensemble_knn_scores = cross_val_predict(ensemble_knn_classifier, X, y_encoded, cv=KFold(n_splits=10, shuffle=True, random_state=42))
ensemble_knn_accuracy = accuracy_score(y_encoded, ensemble_knn_scores)
# ensemble_knn_precision = precision_score(y_encoded, ensemble_knn_scores)
# ensemble_knn_recall = recall_score(y_encoded, ensemble_knn_scores)
# ensemble_knn_f1 = f1_score(y_encoded, ensemble_knn_scores)
# ensemble_knn_processing_time = time.time() - start_time_ensemble_knn

print("\nEnsemble Subspace of k-Nearest Neighbors Metrics:")
print("Accuracy:", ensemble_knn_accuracy)
# print("Precision:", ensemble_knn_precision)
# print("Recall:", ensemble_knn_recall)
# print("F1 Score:", ensemble_knn_f1)
# print("Processing Time:", ensemble_knn_processing_time)

# LSTM Model
def create_lstm_model(input_shape):
    model = Sequential()
    model.add(LSTM(64, input_shape=input_shape, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Convert DataFrame to numpy array
X_np = X.values
X_np = X_np.reshape((X_np.shape[0], 1, X_np.shape[1]))

# 10-fold cross-validation
kfold = KFold(n_splits=10, shuffle=True, random_state=42)

accuracy_scores = []
# precision_scores = []
# recall_scores = []
# f1_scores = []

for train_idx, test_idx in kfold.split(X_np):
    X_train, X_test = X_np[train_idx], X_np[test_idx]
    y_train, y_test = y_encoded[train_idx], y_encoded[test_idx]

    # Create and fit LSTM model
    input_shape = (X_train.shape[1], X_train.shape[2])
    lstm_model = create_lstm_model(input_shape)
    lstm_model.fit(X_train, y_train, epochs=10, batch_size=32, verbose=0)

    # Predictions
    y_pred_probs = lstm_model.predict(X_test)
    y_pred = (y_pred_probs > 0.5).astype(int).flatten()

    # Evaluate metrics
    accuracy_scores.append(accuracy_score(y_test, y_pred))
    # precision_scores.append(precision_score(y_test, y_pred))
    # recall_scores.append(recall_score(y_test, y_pred))
    # f1_scores.append(f1_score(y_test, y_pred))

print("\nLSTM Metrics:")
print("LSTM Model Accuracy:", np.mean(accuracy_scores))
# print("LSTM Model Precision:", np.mean(precision_scores))
# print("LSTM Model Recall:", np.mean(recall_scores))
# print("LSTM Model F1 Score:", np.mean(f1_scores))
# Out:
# SVM Metrics:
# Accuracy: 0.8375541267550191
#
# XGBoost Metrics:
# Accuracy: 0.9098543498228578
#
# Random Forest Metrics:
# Accuracy: 0.8632725364125443
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# Ensemble Subspace of k-Nearest Neighbors Metrics:
# Accuracy: 0.8913528408345361
# 24/24 [==============================] - 0s 2ms/step
# 24/24 [==============================] - 0s 2ms/step
# 24/24 [==============================] - 0s 2ms/step
# 24/24 [==============================] - 0s 1ms/step
# 24/24 [==============================] - 0s 2ms/step
# 24/24 [==============================] - 0s 2ms/step
# 24/24 [==============================] - 0s 2ms/step
# 24/24 [==============================] - 0s 1ms/step
# 24/24 [==============================] - 0s 2ms/step
# 24/24 [==============================] - 0s 2ms/step
#
# LSTM Metrics:
# LSTM Model Accuracy: 0.8013372755011128

# %%
# Assuming 'merged_alpha_a_c' is your DataFrame
X = merged_alpha_a_c.iloc[:, :-1]
y = merged_alpha_a_c.iloc[:, -1]
# Encode the target variable if it's categorical
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

xgb_classifier = XGBClassifier()
xgb_scores = cross_val_score(xgb_classifier, X, y_encoded, cv=KFold(n_splits=10, shuffle=True, random_state=42))
print("XGBoost Mean Accuracy:", xgb_scores.mean())
# Out:
# XGBoost Mean Accuracy: 0.7857237455409816

# %%
# Assuming 'new_dataframe' is your DataFrame
X = merged_delta_a_c.iloc[:, :-1]
y = merged_delta_a_c.iloc[:, -1]

# Encode the target variable if it's categorical
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Support Vector Machine (SVM)
# start_time = time.time()
svm_classifier = make_pipeline(StandardScaler(), SVC())
svm_predictions = cross_val_predict(svm_classifier, X, y_encoded, cv=KFold(n_splits=10, shuffle=True, random_state=42))
svm_accuracy = accuracy_score(y_encoded, svm_predictions)
# svm_precision = precision_score(y_encoded, svm_predictions)
# svm_recall = recall_score(y_encoded, svm_predictions)
# svm_f1 = f1_score(y_encoded, svm_predictions)
# svm_processing_time = time.time() - start_time

print("SVM Metrics:")
print("Accuracy:", svm_accuracy)
# print("Precision:", svm_precision)
# print("Recall:", svm_recall)
# print("F1 Score:", svm_f1)
# print("Processing Time:", svm_processing_time)

# XGBoost
# start_time = time.time()
xgb_classifier = XGBClassifier()
xgb_predictions = cross_val_predict(xgb_classifier, X, y_encoded, cv=KFold(n_splits=10, shuffle=True, random_state=42))
xgb_accuracy = accuracy_score(y_encoded, xgb_predictions)
# xgb_precision = precision_score(y_encoded, xgb_predictions)
# xgb_recall = recall_score(y_encoded, xgb_predictions)
# xgb_f1 = f1_score(y_encoded, xgb_predictions)
# xgb_processing_time = time.time() - start_time

print("\nXGBoost Metrics:")
print("Accuracy:", xgb_accuracy)
# print("Precision:", xgb_precision)
# print("Recall:", xgb_recall)
# print("F1 Score:", xgb_f1)
# print("Processing Time:", xgb_processing_time)

# Random Forest
# start_time = time.time()
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)
rf_predictions = cross_val_predict(rf_classifier, X, y_encoded, cv=KFold(n_splits=10, shuffle=True, random_state=42))
rf_accuracy = accuracy_score(y_encoded, rf_predictions)
# rf_precision = precision_score(y_encoded, rf_predictions)
# rf_recall = recall_score(y_encoded, rf_predictions)
# rf_f1 = f1_score(y_encoded, rf_predictions)
# rf_processing_time = time.time() - start_time

print("\nRandom Forest Metrics:")
print("Accuracy:", rf_accuracy)
# print("Precision:", rf_precision)
# print("Recall:", rf_recall)
# print("F1 Score:", rf_f1)
# print("Processing Time:", rf_processing_time)


# Ensemble Subspace of k-Nearest Neighbors
# start_time_ensemble_knn = time.time()
knn_classifier = KNeighborsClassifier(n_neighbors=5)
ensemble_knn_classifier = BaggingClassifier(base_estimator=knn_classifier, n_estimators=10, random_state=42)

ensemble_knn_scores = cross_val_predict(ensemble_knn_classifier, X, y_encoded, cv=KFold(n_splits=10, shuffle=True, random_state=42))
ensemble_knn_accuracy = accuracy_score(y_encoded, ensemble_knn_scores)
# ensemble_knn_precision = precision_score(y_encoded, ensemble_knn_scores)
# ensemble_knn_recall = recall_score(y_encoded, ensemble_knn_scores)
# ensemble_knn_f1 = f1_score(y_encoded, ensemble_knn_scores)
# ensemble_knn_processing_time = time.time() - start_time_ensemble_knn

print("\nEnsemble Subspace of k-Nearest Neighbors Metrics:")
print("Accuracy:", ensemble_knn_accuracy)
# print("Precision:", ensemble_knn_precision)
# print("Recall:", ensemble_knn_recall)
# print("F1 Score:", ensemble_knn_f1)
# print("Processing Time:", ensemble_knn_processing_time)

# LSTM Model
def create_lstm_model(input_shape):
    model = Sequential()
    model.add(LSTM(64, input_shape=input_shape, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Convert DataFrame to numpy array
X_np = X.values
X_np = X_np.reshape((X_np.shape[0], 1, X_np.shape[1]))

# 10-fold cross-validation
kfold = KFold(n_splits=10, shuffle=True, random_state=42)

accuracy_scores = []
# precision_scores = []
# recall_scores = []
# f1_scores = []

for train_idx, test_idx in kfold.split(X_np):
    X_train, X_test = X_np[train_idx], X_np[test_idx]
    y_train, y_test = y_encoded[train_idx], y_encoded[test_idx]

    # Create and fit LSTM model
    input_shape = (X_train.shape[1], X_train.shape[2])
    lstm_model = create_lstm_model(input_shape)
    lstm_model.fit(X_train, y_train, epochs=10, batch_size=32, verbose=0)

    # Predictions
    y_pred_probs = lstm_model.predict(X_test)
    y_pred = (y_pred_probs > 0.5).astype(int).flatten()

    # Evaluate metrics
    accuracy_scores.append(accuracy_score(y_test, y_pred))
    # precision_scores.append(precision_score(y_test, y_pred))
    # recall_scores.append(recall_score(y_test, y_pred))
    # f1_scores.append(f1_score(y_test, y_pred))

print("\nLSTM Metrics:")
print("LSTM Model Accuracy:", np.mean(accuracy_scores))
# print("LSTM Model Precision:", np.mean(precision_scores))
# print("LSTM Model Recall:", np.mean(recall_scores))
# print("LSTM Model F1 Score:", np.mean(f1_scores))
# Out:
# SVM Metrics:
# Accuracy: 0.6875738092113896
#
# XGBoost Metrics:
# Accuracy: 0.7479333420810917
#
# Random Forest Metrics:
# Accuracy: 0.7144731662511481
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# Ensemble Subspace of k-Nearest Neighbors Metrics:
# Accuracy: 0.6538512006298386
# 24/24 [==============================] - 0s 1ms/step
# 24/24 [==============================] - 0s 2ms/step
# 24/24 [==============================] - 0s 2ms/step
# 24/24 [==============================] - 0s 2ms/step
# 24/24 [==============================] - 0s 3ms/step
# 24/24 [==============================] - 0s 2ms/step
# 24/24 [==============================] - 0s 2ms/step
# 24/24 [==============================] - 0s 2ms/step
# 24/24 [==============================] - 0s 2ms/step
# 24/24 [==============================] - 0s 2ms/step
#
# LSTM Metrics:
# LSTM Model Accuracy: 0.5403494287984644

# %%
# Assuming 'new_dataframe' is your DataFrame
X = merged_gamma_a_c.iloc[:, :-1]
y = merged_gamma_a_c.iloc[:, -1]

# Encode the target variable if it's categorical
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Support Vector Machine (SVM)
# start_time = time.time()
svm_classifier = make_pipeline(StandardScaler(), SVC())
svm_predictions = cross_val_predict(svm_classifier, X, y_encoded, cv=KFold(n_splits=10, shuffle=True, random_state=42))
svm_accuracy = accuracy_score(y_encoded, svm_predictions)
# svm_precision = precision_score(y_encoded, svm_predictions)
# svm_recall = recall_score(y_encoded, svm_predictions)
# svm_f1 = f1_score(y_encoded, svm_predictions)
# svm_processing_time = time.time() - start_time

print("SVM Metrics:")
print("Accuracy:", svm_accuracy)
# print("Precision:", svm_precision)
# print("Recall:", svm_recall)
# print("F1 Score:", svm_f1)
# print("Processing Time:", svm_processing_time)

# XGBoost
# start_time = time.time()
xgb_classifier = XGBClassifier()
xgb_predictions = cross_val_predict(xgb_classifier, X, y_encoded, cv=KFold(n_splits=10, shuffle=True, random_state=42))
xgb_accuracy = accuracy_score(y_encoded, xgb_predictions)
# xgb_precision = precision_score(y_encoded, xgb_predictions)
# xgb_recall = recall_score(y_encoded, xgb_predictions)
# xgb_f1 = f1_score(y_encoded, xgb_predictions)
# xgb_processing_time = time.time() - start_time

print("\nXGBoost Metrics:")
print("Accuracy:", xgb_accuracy)
# print("Precision:", xgb_precision)
# print("Recall:", xgb_recall)
# print("F1 Score:", xgb_f1)
# print("Processing Time:", xgb_processing_time)

# Random Forest
# start_time = time.time()
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)
rf_predictions = cross_val_predict(rf_classifier, X, y_encoded, cv=KFold(n_splits=10, shuffle=True, random_state=42))
rf_accuracy = accuracy_score(y_encoded, rf_predictions)
# rf_precision = precision_score(y_encoded, rf_predictions)
# rf_recall = recall_score(y_encoded, rf_predictions)
# rf_f1 = f1_score(y_encoded, rf_predictions)
# rf_processing_time = time.time() - start_time

print("\nRandom Forest Metrics:")
print("Accuracy:", rf_accuracy)
# print("Precision:", rf_precision)
# print("Recall:", rf_recall)
# print("F1 Score:", rf_f1)
# print("Processing Time:", rf_processing_time)


# Ensemble Subspace of k-Nearest Neighbors
# start_time_ensemble_knn = time.time()
knn_classifier = KNeighborsClassifier(n_neighbors=5)
ensemble_knn_classifier = BaggingClassifier(base_estimator=knn_classifier, n_estimators=10, random_state=42)

ensemble_knn_scores = cross_val_predict(ensemble_knn_classifier, X, y_encoded, cv=KFold(n_splits=10, shuffle=True, random_state=42))
ensemble_knn_accuracy = accuracy_score(y_encoded, ensemble_knn_scores)
# ensemble_knn_precision = precision_score(y_encoded, ensemble_knn_scores)
# ensemble_knn_recall = recall_score(y_encoded, ensemble_knn_scores)
# ensemble_knn_f1 = f1_score(y_encoded, ensemble_knn_scores)
# ensemble_knn_processing_time = time.time() - start_time_ensemble_knn

print("\nEnsemble Subspace of k-Nearest Neighbors Metrics:")
print("Accuracy:", ensemble_knn_accuracy)
# print("Precision:", ensemble_knn_precision)
# print("Recall:", ensemble_knn_recall)
# print("F1 Score:", ensemble_knn_f1)
# print("Processing Time:", ensemble_knn_processing_time)

# LSTM Model
def create_lstm_model(input_shape):
    model = Sequential()
    model.add(LSTM(64, input_shape=input_shape, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Convert DataFrame to numpy array
X_np = X.values
X_np = X_np.reshape((X_np.shape[0], 1, X_np.shape[1]))

# 10-fold cross-validation
kfold = KFold(n_splits=10, shuffle=True, random_state=42)

accuracy_scores = []
# precision_scores = []
# recall_scores = []
# f1_scores = []

for train_idx, test_idx in kfold.split(X_np):
    X_train, X_test = X_np[train_idx], X_np[test_idx]
    y_train, y_test = y_encoded[train_idx], y_encoded[test_idx]

    # Create and fit LSTM model
    input_shape = (X_train.shape[1], X_train.shape[2])
    lstm_model = create_lstm_model(input_shape)
    lstm_model.fit(X_train, y_train, epochs=10, batch_size=32, verbose=0)

    # Predictions
    y_pred_probs = lstm_model.predict(X_test)
    y_pred = (y_pred_probs > 0.5).astype(int).flatten()

    # Evaluate metrics
    accuracy_scores.append(accuracy_score(y_test, y_pred))
    # precision_scores.append(precision_score(y_test, y_pred))
    # recall_scores.append(recall_score(y_test, y_pred))
    # f1_scores.append(f1_score(y_test, y_pred))

print("\nLSTM Metrics:")
print("LSTM Model Accuracy:", np.mean(accuracy_scores))
# print("LSTM Model Precision:", np.mean(precision_scores))
# print("LSTM Model Recall:", np.mean(recall_scores))
# print("LSTM Model F1 Score:", np.mean(f1_scores))
# Out:
# SVM Metrics:
# Accuracy: 0.8463456239338669
#
# XGBoost Metrics:
# Accuracy: 0.9574858942396011
#
# Random Forest Metrics:
# Accuracy: 0.9278309933079648
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# Ensemble Subspace of k-Nearest Neighbors Metrics:
# Accuracy: 0.9430520929011941
# 24/24 [==============================] - 0s 2ms/step
# 24/24 [==============================] - 0s 2ms/step
# 24/24 [==============================] - 0s 2ms/step
# 24/24 [==============================] - 0s 1ms/step
# 24/24 [==============================] - 0s 3ms/step
# 24/24 [==============================] - 0s 2ms/step
# 24/24 [==============================] - 0s 2ms/step
# 24/24 [==============================] - 0s 2ms/step
# 24/24 [==============================] - 0s 2ms/step
# 24/24 [==============================] - 0s 2ms/step
#
# LSTM Metrics:
# LSTM Model Accuracy: 0.9196955311778687

# %%
# Assuming 'new_dataframe' is your DataFrame
X = merged_theta_a_c.iloc[:, :-1]
y = merged_theta_a_c.iloc[:, -1]

# Encode the target variable if it's categorical
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Support Vector Machine (SVM)
# start_time = time.time()
svm_classifier = make_pipeline(StandardScaler(), SVC())
svm_predictions = cross_val_predict(svm_classifier, X, y_encoded, cv=KFold(n_splits=10, shuffle=True, random_state=42))
svm_accuracy = accuracy_score(y_encoded, svm_predictions)
# svm_precision = precision_score(y_encoded, svm_predictions)
# svm_recall = recall_score(y_encoded, svm_predictions)
# svm_f1 = f1_score(y_encoded, svm_predictions)
# svm_processing_time = time.time() - start_time

print("SVM Metrics:")
print("Accuracy:", svm_accuracy)
# print("Precision:", svm_precision)
# print("Recall:", svm_recall)
# print("F1 Score:", svm_f1)
# print("Processing Time:", svm_processing_time)

# XGBoost
# start_time = time.time()
xgb_classifier = XGBClassifier()
xgb_predictions = cross_val_predict(xgb_classifier, X, y_encoded, cv=KFold(n_splits=10, shuffle=True, random_state=42))
xgb_accuracy = accuracy_score(y_encoded, xgb_predictions)
# xgb_precision = precision_score(y_encoded, xgb_predictions)
# xgb_recall = recall_score(y_encoded, xgb_predictions)
# xgb_f1 = f1_score(y_encoded, xgb_predictions)
# xgb_processing_time = time.time() - start_time

print("\nXGBoost Metrics:")
print("Accuracy:", xgb_accuracy)
# print("Precision:", xgb_precision)
# print("Recall:", xgb_recall)
# print("F1 Score:", xgb_f1)
# print("Processing Time:", xgb_processing_time)

# Random Forest
# start_time = time.time()
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)
rf_predictions = cross_val_predict(rf_classifier, X, y_encoded, cv=KFold(n_splits=10, shuffle=True, random_state=42))
rf_accuracy = accuracy_score(y_encoded, rf_predictions)
# rf_precision = precision_score(y_encoded, rf_predictions)
# rf_recall = recall_score(y_encoded, rf_predictions)
# rf_f1 = f1_score(y_encoded, rf_predictions)
# rf_processing_time = time.time() - start_time

print("\nRandom Forest Metrics:")
print("Accuracy:", rf_accuracy)
# print("Precision:", rf_precision)
# print("Recall:", rf_recall)
# print("F1 Score:", rf_f1)
# print("Processing Time:", rf_processing_time)


# Ensemble Subspace of k-Nearest Neighbors
# start_time_ensemble_knn = time.time()
knn_classifier = KNeighborsClassifier(n_neighbors=5)
ensemble_knn_classifier = BaggingClassifier(base_estimator=knn_classifier, n_estimators=10, random_state=42)

ensemble_knn_scores = cross_val_predict(ensemble_knn_classifier, X, y_encoded, cv=KFold(n_splits=10, shuffle=True, random_state=42))
ensemble_knn_accuracy = accuracy_score(y_encoded, ensemble_knn_scores)
# ensemble_knn_precision = precision_score(y_encoded, ensemble_knn_scores)
# ensemble_knn_recall = recall_score(y_encoded, ensemble_knn_scores)
# ensemble_knn_f1 = f1_score(y_encoded, ensemble_knn_scores)
# ensemble_knn_processing_time = time.time() - start_time_ensemble_knn

print("\nEnsemble Subspace of k-Nearest Neighbors Metrics:")
print("Accuracy:", ensemble_knn_accuracy)
# print("Precision:", ensemble_knn_precision)
# print("Recall:", ensemble_knn_recall)
# print("F1 Score:", ensemble_knn_f1)
# print("Processing Time:", ensemble_knn_processing_time)

# LSTM Model
def create_lstm_model(input_shape):
    model = Sequential()
    model.add(LSTM(64, input_shape=input_shape, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Convert DataFrame to numpy array
X_np = X.values
X_np = X_np.reshape((X_np.shape[0], 1, X_np.shape[1]))

# 10-fold cross-validation
kfold = KFold(n_splits=10, shuffle=True, random_state=42)

accuracy_scores = []
# precision_scores = []
# recall_scores = []
# f1_scores = []

for train_idx, test_idx in kfold.split(X_np):
    X_train, X_test = X_np[train_idx], X_np[test_idx]
    y_train, y_test = y_encoded[train_idx], y_encoded[test_idx]

    # Create and fit LSTM model
    input_shape = (X_train.shape[1], X_train.shape[2])
    lstm_model = create_lstm_model(input_shape)
    lstm_model.fit(X_train, y_train, epochs=10, batch_size=32, verbose=0)

    # Predictions
    y_pred_probs = lstm_model.predict(X_test)
    y_pred = (y_pred_probs > 0.5).astype(int).flatten()

    # Evaluate metrics
    accuracy_scores.append(accuracy_score(y_test, y_pred))
    # precision_scores.append(precision_score(y_test, y_pred))
    # recall_scores.append(recall_score(y_test, y_pred))
    # f1_scores.append(f1_score(y_test, y_pred))

print("\nLSTM Metrics:")
print("LSTM Model Accuracy:", np.mean(accuracy_scores))
# print("LSTM Model Precision:", np.mean(precision_scores))
# print("LSTM Model Recall:", np.mean(recall_scores))
# print("LSTM Model F1 Score:", np.mean(f1_scores))
# Out:
# SVM Metrics:
# Accuracy: 0.7380921138958142
#
# XGBoost Metrics:
# Accuracy: 0.7803437869046057
#
# Random Forest Metrics:
# Accuracy: 0.7500328040939509
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# Ensemble Subspace of k-Nearest Neighbors Metrics:
# Accuracy: 0.7228710143025849
# 24/24 [==============================] - 0s 2ms/step
# 24/24 [==============================] - 0s 3ms/step
# 24/24 [==============================] - 0s 2ms/step
# 24/24 [==============================] - 0s 2ms/step
# 24/24 [==============================] - 0s 2ms/step
# 24/24 [==============================] - 0s 2ms/step
# 24/24 [==============================] - 0s 2ms/step
# 24/24 [==============================] - 0s 3ms/step
# 24/24 [==============================] - 0s 2ms/step
# 24/24 [==============================] - 0s 3ms/step
#
# LSTM Metrics:
# LSTM Model Accuracy: 0.6425635442358696

# %%
merged_alpha_Katz_a_c = pd.concat([merged_alpha_a_c,Katz_Fd_Features_a_c], axis=1)
merged_alpha_Katz_a_c.drop('label', axis=1, inplace=True)
merged_alpha_Katz_a_c['label']='normal'
merged_alpha_Katz_a_c.loc[0:3810, 'label'] = 'addicted'
merged_alpha_Katz_a_c
# Out:
#           FP1_PS      FP2_PS       F7_PS       F8_PS      AF1_PS      AF2_PS  \
# 0     151.357655  114.738791   32.700180   94.090966   73.499523   78.755574
# 1      24.377114   24.409820   35.402792   74.120890   19.066220   28.625885
# 2      53.604690   52.229281   33.690667  134.966372   34.509084   23.349252
# 3     163.679392  175.686733   50.198667   81.434263   85.962690   62.958800
# 4      56.770827   77.169951   53.130566  108.774206   30.604726   36.274900
# ...          ...         ...         ...         ...         ...         ...
# 7616  389.040034  394.828751  366.835301  339.928901  304.304614  301.450732
# 7617  249.367893  211.371395  296.404474  192.848368  167.894608  155.813059
# 7618  526.722250  500.074773  435.809033  311.024832  440.805728  450.093463
# 7619  444.402023  485.756174  531.422840  689.832870  322.385563  339.572831
# 7621  158.945856  106.954632  470.234070  146.905278  134.518361   96.155223
#
#            FZ_PS       F4_PS       F3_PS      FC6_PS  ...      FCZ_PS  \
# 0      27.267203   49.861958   34.894815   16.539714  ...    7.232680
# 1      13.257787   33.826245   12.287058   39.515352  ...    5.121506
# 2      14.864071   36.951631   20.357905   14.222105  ...    3.244246
# 3      46.865131   39.923870   31.735375   41.925672  ...   13.514941
# 4      12.336038   15.918106   14.974728   32.559235  ...    5.204390
# ...          ...         ...         ...         ...  ...         ...
# 7616  228.974817  235.828400  218.494023  219.801846  ...   76.920201
# 7617  141.272444  210.457679  166.609699  105.234983  ...   69.586962
# 7618  369.094390  398.763052  402.230341  246.810946  ...  156.482016
# 7619  192.223393  278.486812  234.051621  431.437484  ...   67.206469
# 7621   83.051055   84.555932  180.928509  116.782595  ...   56.389875
#
#            POZ_PS        OZ_PS       P2_PS       P1_PS      CPZ_PS  \
# 0       41.337346    75.797028   20.759074   16.402765    3.899377
# 1       41.490513    93.046992   18.263348   21.610488    2.861285
# 2       21.879878    50.497185   11.924356    7.255095    1.474022
# 3       67.504139   150.342625   41.962119   35.416218    6.447408
# 4       77.190465   128.010694   41.792296   34.782381    5.681607
# ...           ...          ...         ...         ...         ...
# 7616   202.276045   560.746945  174.248368   84.105860  116.515643
# 7617  1572.154752  1557.831341  882.133315  920.169438  256.651599
# 7618   678.108185   770.114744  377.573122  369.463303  218.213197
# 7619   865.588487   704.500952  447.445965  536.314523  166.459891
# 7621   304.889810   463.097292  206.877824  193.549605  124.443189
#
#             nd_PS         Y_PS       FP2     label
# 0      144.276264    53.095701  1.655864  addicted
# 1       23.275233    65.173012  1.367933  addicted
# 2       54.021975    55.217999  1.584968  addicted
# 3      159.025641    52.490226  1.282758  addicted
# 4       53.253073    63.363475  1.461674  addicted
# ...           ...          ...       ...       ...
# 7616   640.019394   702.251079  1.819097    normal
# 7617  2400.332807   464.892665  1.538744    normal
# 7618   948.275897   664.145591  1.716444    normal
# 7619   736.439827  1115.076239  1.556286    normal
# 7621   529.926392   594.527443  1.598684    normal
#
# [7621 rows x 66 columns]

# %%
merged_beta_Katz_a_c = pd.concat([merged_beta_a_c,Katz_Fd_Features_a_c], axis=1)
merged_beta_Katz_a_c.drop('label', axis=1, inplace=True)
merged_beta_Katz_a_c['label']='normal'
merged_beta_Katz_a_c.loc[0:3810, 'label'] = 'addicted'
# merged_beta_Katz_a_c

# %%
merged_gamma_Katz_a_c = pd.concat([merged_gamma_a_c,Katz_Fd_Features_a_c], axis=1)
merged_gamma_Katz_a_c.drop('label', axis=1, inplace=True)
merged_gamma_Katz_a_c['label']='normal'
merged_gamma_Katz_a_c.loc[0:3810, 'label'] = 'addicted'

# %%
merged_delta_Katz_a_c = pd.concat([merged_delta_a_c,Katz_Fd_Features_a_c], axis=1)
merged_delta_Katz_a_c.drop('label', axis=1, inplace=True)
merged_delta_Katz_a_c['label']='normal'
merged_delta_Katz_a_c.loc[0:3810, 'label'] = 'addicted'

# %%
merged_theta_Katz_a_c = pd.concat([merged_theta_a_c,Katz_Fd_Features_a_c], axis=1)
merged_theta_Katz_a_c.drop('label', axis=1, inplace=True)
merged_theta_Katz_a_c['label']='normal'
merged_theta_Katz_a_c.loc[0:3810, 'label'] = 'addicted'

# %%
# Assuming 'new_dataframe' is your DataFrame
X = merged_alpha_Katz_a_c.iloc[:, :-1]
y = merged_alpha_Katz_a_c.iloc[:, -1]

# Encode the target variable if it's categorical
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Support Vector Machine (SVM)
# start_time = time.time()
svm_classifier = make_pipeline(StandardScaler(), SVC())
svm_predictions = cross_val_predict(svm_classifier, X, y_encoded, cv=KFold(n_splits=10, shuffle=True, random_state=42))
svm_accuracy = accuracy_score(y_encoded, svm_predictions)
# svm_precision = precision_score(y_encoded, svm_predictions)
# svm_recall = recall_score(y_encoded, svm_predictions)
# svm_f1 = f1_score(y_encoded, svm_predictions)
# svm_processing_time = time.time() - start_time

print("SVM Metrics:")
print("Accuracy:", svm_accuracy)
# print("Precision:", svm_precision)
# print("Recall:", svm_recall)
# print("F1 Score:", svm_f1)
# print("Processing Time:", svm_processing_time)

# XGBoost
# start_time = time.time()
xgb_classifier = XGBClassifier()
xgb_predictions = cross_val_predict(xgb_classifier, X, y_encoded, cv=KFold(n_splits=10, shuffle=True, random_state=42))
xgb_accuracy = accuracy_score(y_encoded, xgb_predictions)
# xgb_precision = precision_score(y_encoded, xgb_predictions)
# xgb_recall = recall_score(y_encoded, xgb_predictions)
# xgb_f1 = f1_score(y_encoded, xgb_predictions)
# xgb_processing_time = time.time() - start_time

print("\nXGBoost Metrics:")
print("Accuracy:", xgb_accuracy)
# print("Precision:", xgb_precision)
# print("Recall:", xgb_recall)
# print("F1 Score:", xgb_f1)
# print("Processing Time:", xgb_processing_time)

# Random Forest
# start_time = time.time()
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)
rf_predictions = cross_val_predict(rf_classifier, X, y_encoded, cv=KFold(n_splits=10, shuffle=True, random_state=42))
rf_accuracy = accuracy_score(y_encoded, rf_predictions)
# rf_precision = precision_score(y_encoded, rf_predictions)
# rf_recall = recall_score(y_encoded, rf_predictions)
# rf_f1 = f1_score(y_encoded, rf_predictions)
# rf_processing_time = time.time() - start_time

print("\nRandom Forest Metrics:")
print("Accuracy:", rf_accuracy)
# print("Precision:", rf_precision)
# print("Recall:", rf_recall)
# print("F1 Score:", rf_f1)
# print("Processing Time:", rf_processing_time)


# Ensemble Subspace of k-Nearest Neighbors
# start_time_ensemble_knn = time.time()
knn_classifier = KNeighborsClassifier(n_neighbors=5)
ensemble_knn_classifier = BaggingClassifier(base_estimator=knn_classifier, n_estimators=10, random_state=42)

ensemble_knn_scores = cross_val_predict(ensemble_knn_classifier, X, y_encoded, cv=KFold(n_splits=10, shuffle=True, random_state=42))
ensemble_knn_accuracy = accuracy_score(y_encoded, ensemble_knn_scores)
# ensemble_knn_precision = precision_score(y_encoded, ensemble_knn_scores)
# ensemble_knn_recall = recall_score(y_encoded, ensemble_knn_scores)
# ensemble_knn_f1 = f1_score(y_encoded, ensemble_knn_scores)
# ensemble_knn_processing_time = time.time() - start_time_ensemble_knn

print("\nEnsemble Subspace of k-Nearest Neighbors Metrics:")
print("Accuracy:", ensemble_knn_accuracy)
# print("Precision:", ensemble_knn_precision)
# print("Recall:", ensemble_knn_recall)
# print("F1 Score:", ensemble_knn_f1)
# print("Processing Time:", ensemble_knn_processing_time)

# LSTM Model
def create_lstm_model(input_shape):
    model = Sequential()
    model.add(LSTM(64, input_shape=input_shape, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Convert DataFrame to numpy array
X_np = X.values
X_np = X_np.reshape((X_np.shape[0], 1, X_np.shape[1]))

# 10-fold cross-validation
kfold = KFold(n_splits=10, shuffle=True, random_state=42)

accuracy_scores = []
# precision_scores = []
# recall_scores = []
# f1_scores = []

for train_idx, test_idx in kfold.split(X_np):
    X_train, X_test = X_np[train_idx], X_np[test_idx]
    y_train, y_test = y_encoded[train_idx], y_encoded[test_idx]

    # Create and fit LSTM model
    input_shape = (X_train.shape[1], X_train.shape[2])
    lstm_model = create_lstm_model(input_shape)
    lstm_model.fit(X_train, y_train, epochs=10, batch_size=32, verbose=0)

    # Predictions
    y_pred_probs = lstm_model.predict(X_test)
    y_pred = (y_pred_probs > 0.5).astype(int).flatten()

    # Evaluate metrics
    accuracy_scores.append(accuracy_score(y_test, y_pred))
    # precision_scores.append(precision_score(y_test, y_pred))
    # recall_scores.append(recall_score(y_test, y_pred))
    # f1_scores.append(f1_score(y_test, y_pred))

print("\nLSTM Metrics:")
print("LSTM Model Accuracy:", np.mean(accuracy_scores))
# print("LSTM Model Precision:", np.mean(precision_scores))
# print("LSTM Model Recall:", np.mean(recall_scores))
# print("LSTM Model F1 Score:", np.mean(f1_scores))
# Out:
# SVM Metrics:
# Accuracy: 0.7311376459782181
#
# XGBoost Metrics:
# Accuracy: 0.7897913659624721
#
# Random Forest Metrics:
# Accuracy: 0.7544941608712767
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# Ensemble Subspace of k-Nearest Neighbors Metrics:
# Accuracy: 0.7299566985959848
# 24/24 [==============================] - 0s 2ms/step
# 24/24 [==============================] - 0s 3ms/step
# 24/24 [==============================] - 0s 2ms/step
# 24/24 [==============================] - 0s 3ms/step
# 24/24 [==============================] - 0s 2ms/step
# 24/24 [==============================] - 0s 2ms/step
# 24/24 [==============================] - 0s 2ms/step
# 24/24 [==============================] - 0s 2ms/step
# 24/24 [==============================] - 0s 2ms/step
# 24/24 [==============================] - 0s 2ms/step
#
# LSTM Metrics:
# LSTM Model Accuracy: 0.6412527562495056
